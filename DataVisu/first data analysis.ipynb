# %%
import pandas as pd
from matplotlib import pyplot as plt
x = [1,2,3,4]
y = [5,6,7,8]
z = [1,8,6,9]
plt.plot(x,y)
plt.plot(x,z)
plt.plot(z,y)
plt.xlabel("some random number")
plt.ylabel("Some random number 2")
plt.legend(["basic xy", "basic xz","basic zy"])
plt.show()
